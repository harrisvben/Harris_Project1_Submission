# %% [markdown]
# ## DS2002 Project 1, Ben Harris - NRA2JE
#
#
# #### Import Necessary Libraries

# %%
import os
import json
import csv
import numpy
import datetime
import certifi
import pandas as pd

import pymongo
import sqlalchemy
from sqlalchemy import create_engine

# %% [markdown]
# #### Connections for SQL and MondoDB Atlas

# %%
mysql_args = {
    "uid" : "root",
    "pwd" : "Passw0rd123",
    "hostname" : "localhost",
    "dbname" : "datamart"
}

mongodb_args = {
    "user_name" : "nra2je",
    "password" : "Passw0rd123",
    "cluster_name" : "sandbox",
    "cluster_subnet" : "4mvrkqg",
    "cluster_location" : "atlas",
    "db_name" : "Harris_Project_1"
}

# %% [markdown]
# #### Functions for Getting Data From and Setting Data Into Databases

# %%
def get_sql_dataframe(sql_query, **args):
    '''Create a connection to the MySQL database'''
    conn_str = f"mysql+pymysql://{args['uid']}:{args['pwd']}@{args['hostname']}/{args['dbname']}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    '''Invoke the pd.read_sql() function to query the database, and fill a Pandas DataFrame.'''
    dframe = pd.read_sql(sql_query, connection);
    connection.close()
    
    return dframe
    

def set_dataframe(df, table_name, pk_column, db_operation, **args):
    '''Create a connection to the MySQL database'''
    conn_str = f"mysql+pymysql://{args['uid']}:{args['pwd']}@{args['hostname']}/{args['dbname']}"
    sqlEngine = create_engine(conn_str, pool_recycle=3600)
    connection = sqlEngine.connect()
    
    '''Invoke the Pandas DataFrame .to_sql( ) function to either create, or append to, a table'''
    if db_operation == "insert":
        df.to_sql(table_name, con=connection, index=False, if_exists='replace')
        connection.execute(f"ALTER TABLE {table_name} ADD PRIMARY KEY ({pk_column});")
            
    elif db_operation == "update":
        df.to_sql(table_name, con=connection, index=False, if_exists='append')
    
    connection.close()


def get_mongo_client(**args):
    '''Validate proper input'''
    if args["cluster_location"] not in ['atlas', 'local']:
        raise Exception("You must specify either 'atlas' or 'local' for the cluster_location parameter.")
    
    else:
        if args["cluster_location"] == "atlas":
            connect_str = f"mongodb+srv://{args['user_name']}:{args['password']}@"
            connect_str += f"{args['cluster_name']}.{args['cluster_subnet']}.mongodb.net"
            client = pymongo.MongoClient(connect_str, tlsCAFile=certifi.where())
            
        elif args["cluster_location"] == "local":
            client = pymongo.MongoClient("mongodb://localhost:27017/")
        
    return client


def get_mongo_dataframe(mongo_client, db_name, collection, query):
    '''Query MongoDB, and fill a python list with documents to create a DataFrame'''
    db = mongo_client[db_name]
    dframe = pd.DataFrame(list(db[collection].find(query)))
    dframe.drop(['_id'], axis=1, inplace=True)
    mongo_client.close()
    
    return dframe


def set_mongo_collections(client, db_name, data_directory, csv_files):
    db = client[db_name]
    
    for collection_name, csv_file in csv_files.items():
        db[collection_name].drop()
        csv_path = os.path.join(data_directory, csv_file)
        df = pd.read_csv(csv_path)
        records = df.to_dict(orient='records')
        db[collection_name].insert_many(records)
    
    client.close()

# %% [markdown]
# #### Populate MobgoDB with data

# %%
client = get_mongo_client(**mongodb_args)


data_dir = os.path.join(os.getcwd(), 'Data')

csv_files = {"sales" : 'sales_data.csv',
             "stores" : 'stores_data.csv',
             "inspectors" : 'inspector_data.csv'
            }

set_mongo_collections(client, mongodb_args["db_name"], data_dir, csv_files)

# %% [markdown]
# #### Extract MongoDB Collections into Pandas DataFrames

# %%
client = get_mongo_client(**mongodb_args)

query = {}
collection = "stores"

df_stores = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_stores.head(2)
# Out:
#    Store Type    Size     State         City  \
# 0      1    A  151315  Illinois  Bourbonnais
# 1      2    A  202307  Illinois      Chicago
#
#                                           Address
# 0  1601 N State Route 50 Bourbonnais, IL 60914 US
# 1          41 W. 87th Street Chicago, IL 60620 US

# %%
client = get_mongo_client(**mongodb_args)

query = {}
collection = "inspectors"

df_inspectors = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_inspectors.head(2)
# Out:
#    Inspector_ID First    Last                     Email
# 0             1  Luke  Gentry  lukegentry@retailinc.com
# 1             2   Pam   Brown    pambrown@retailinc.com

# %%
client = get_mongo_client(**mongodb_args)

query = {}
collection = "sales"

df_fact_sales = get_mongo_dataframe(client, mongodb_args["db_name"], collection, query)
df_fact_sales.head(2)
# Out:
#    Store  Dept  Inspector       Date  Weekly_Sales  IsHoliday
# 0      1     1          2   5/2/2010      24924.50      False
# 1      1     1          2  12/2/2010      46039.49       True

# %% [markdown]
# #### Get data from Dim Date Table

# %%
sql_dim_date = "SELECT date_key, full_date FROM datamart.dim_date;"
df_dim_date = get_sql_dataframe(sql_dim_date, **mysql_args)
df_dim_date.full_date = df_dim_date.full_date.astype('datetime64[ns]').dt.date
df_dim_date.head(2)
# Out:
#    date_key   full_date
# 0  20000101  2000-01-01
# 1  20000102  2000-01-02

# %%
df_dim_sales_date = df_dim_date.rename(columns={"date_key" : "sale_date_key", "full_date" : "Date"})
df_fact_sales.Date = df_fact_sales.Date.astype('datetime64[ns]').dt.date
df_fact_sales = pd.merge(df_fact_sales, df_dim_sales_date, on='Date', how='left')
df_fact_sales.drop(['Date'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
# C:\Users\ds2002-student\AppData\Local\Temp\2\ipykernel_5408\521758706.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_fact_sales.Date = df_fact_sales.Date.astype('datetime64[ns]').dt.date
#    Store  Dept  Inspector  Weekly_Sales  IsHoliday  sale_date_key
# 0      1     1          2      24924.50      False     20100502.0
# 1      1     1          2      46039.49       True     20101202.0

# %% [markdown]
# #### Transform DataFrames

# %%
df_stores.rename(columns={"Store":"store_id"}, inplace=True)
df_stores.insert(0, "store_key", range(1, df_stores.shape[0]+1))
df_stores.head(2)
# Out:
#    store_key  store_id Type    Size     State         City  \
# 0          1         1    A  151315  Illinois  Bourbonnais
# 1          2         2    A  202307  Illinois      Chicago
#
#                                           Address
# 0  1601 N State Route 50 Bourbonnais, IL 60914 US
# 1          41 W. 87th Street Chicago, IL 60620 US

# %%
df_inspectors.rename(columns={"Inspector_ID":"inspector_id"}, inplace=True)
df_inspectors.insert(0, "inspector_key", range(1, df_inspectors.shape[0]+1))
df_inspectors.head(2)
# Out:
#    inspector_key  inspector_id First    Last                     Email
# 0              1             1  Luke  Gentry  lukegentry@retailinc.com
# 1              2             2   Pam   Brown    pambrown@retailinc.com

# %%
df_fact_sales.insert(0, "sale_key", range(1, df_fact_sales.shape[0]+1))
df_fact_sales.rename(columns={"Inspector":"inspector_id","Store":"store_id"}, inplace=True)
df_fact_sales.head(2)
# Out:
#    sale_key  store_id  Dept  inspector_id  Weekly_Sales  IsHoliday  \
# 0         1         1     1             2      24924.50      False
# 1         2         1     1             2      46039.49       True
#
#    sale_date_key
# 0     20100502.0
# 1     20101202.0

# %% [markdown]
# #### Load DataFrames into SQL

# %%
dataframe = df_fact_sales
table_name = 'fact_sales'
primary_key = 'sale_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
dataframe = df_stores
table_name = 'dim_stores'
primary_key = 'store_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %%
dataframe = df_inspectors
table_name = 'dim_inspectors'
primary_key = 'inspector_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %% [markdown]
# #### Validate added to SQL

# %%
sql_stores = "SELECT * FROM datamart.dim_stores;"
df_dim_stores = get_sql_dataframe(sql_stores, **mysql_args)
df_dim_stores.head(2)
# Out:
#    store_key  store_id Type    Size     State         City  \
# 0          1         1    A  151315  Illinois  Bourbonnais
# 1          2         2    A  202307  Illinois      Chicago
#
#                                           Address
# 0  1601 N State Route 50 Bourbonnais, IL 60914 US
# 1          41 W. 87th Street Chicago, IL 60620 US

# %%
sql_inspectors = "SELECT * FROM datamart.dim_inspectors;"
df_dim_inspectors = get_sql_dataframe(sql_inspectors, **mysql_args)
df_dim_inspectors.head(2)
# Out:
#    inspector_key  inspector_id First    Last                     Email
# 0              1             1  Luke  Gentry  lukegentry@retailinc.com
# 1              2             2   Pam   Brown    pambrown@retailinc.com

# %%
sql_fact_sales = "SELECT * FROM datamart.fact_sales;"
df_fact_sales = get_sql_dataframe(sql_fact_sales, **mysql_args)
df_fact_sales.head(2)
# Out:
#    sale_key  store_id  Dept  inspector_id  Weekly_Sales  IsHoliday  \
# 0         1         1     1             2      24924.50          0
# 1         2         1     1             2      46039.49          1
#
#    sale_date_key
# 0     20100502.0
# 1     20101202.0

# %% [markdown]
# #### Get Primary Keys from Dimension Tables and Fact Table

# %%
sql_dim_stores = "SELECT store_key, store_id FROM datamart.dim_stores;"
df_dim_stores = get_sql_dataframe(sql_dim_stores, **mysql_args)
df_dim_stores.head(2)
# Out:
#    store_key  store_id
# 0          1         1
# 1          2         2

# %%
sql_dim_inspectors = "SELECT inspector_key, inspector_id FROM datamart.dim_inspectors;"
df_dim_inspectors = get_sql_dataframe(sql_dim_inspectors, **mysql_args)
df_dim_inspectors.head(2)
# Out:
#    inspector_key  inspector_id
# 0              1             1
# 1              2             2

# %%
df_fact_sales = pd.merge(df_fact_sales, df_dim_stores, on='store_id', how='inner')
df_fact_sales.drop(['store_id'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    sale_key  Dept  inspector_id  Weekly_Sales  IsHoliday  sale_date_key  \
# 0         1     1             2      24924.50          0     20100502.0
# 1         2     1             2      46039.49          1     20101202.0
#
#    store_key
# 0          1
# 1          1

# %%
df_fact_sales = pd.merge(df_fact_sales, df_dim_inspectors, on='inspector_id', how='inner')
df_fact_sales.drop(['inspector_id'], axis=1, inplace=True)
df_fact_sales.head(2)
# Out:
#    sale_key  Dept  Weekly_Sales  IsHoliday  sale_date_key  store_key  \
# 0         1     1      24924.50          0     20100502.0          1
# 1         2     1      46039.49          1     20101202.0          1
#
#    inspector_key
# 0              2
# 1              2

# %% [markdown]
# #### Load MongoDB data into SQL database

# %%
dataframe = df_fact_sales
table_name = 'fact_sales'
primary_key = 'sale_key'
db_operation = "insert"

set_dataframe(dataframe, table_name, primary_key, db_operation, **mysql_args)

# %% [markdown]
# #### Validate

# %%
sql_sales_validation = """
SELECT *
FROM datamart.fact_sales
"""
df_sales_validation = get_sql_dataframe(sql_sales_validation, **mysql_args)
df_sales_validation.head(2)
# Out:
#    sale_key  Dept  Weekly_Sales  IsHoliday  sale_date_key  store_key  \
# 0         1     1      24924.50          0     20100502.0          1
# 1         2     1      46039.49          1     20101202.0          1
#
#    inspector_key
# 0              2
# 1              2

# %% [markdown]
# ### Demonstrate Proper Functionality
# #### Displays location, average sales, and total sales for each store

# %%
sql_sales = """
SELECT 
    st.store_id AS Store_Number,
    st.Address AS Store_Location,
    CONCAT('$', FORMAT(AVG(s.Weekly_Sales), 0)) AS Average_Weekly_Sales,
    CONCAT('$', FORMAT(SUM(s.Weekly_Sales), 0)) AS Total_Sales
FROM 
    datamart.fact_sales s
JOIN 
    datamart.dim_stores st ON s.store_key = st.store_key
GROUP BY 
    st.store_id,
    st.Address;
"""

# %%
df_fact_sales = get_sql_dataframe(sql_sales, **mysql_args)
df_fact_sales
# Out:
#     Store_Number                                     Store_Location  \
# 0              1     1601 N State Route 50 Bourbonnais, IL 60914 US
# 1              2             41 W. 87th Street Chicago, IL 60620 US
# 2              3                601 King St Alexandria, VA 22314 US
# 3              4              235 S State St Ann Arbor, MI 48104 US
# 4              5               1081 Pine Plaza Dr Apex, NC 27523 US
# 5              6           48557 Morongo Trail Cabazon, CA 92230 US
# 6              7              5 Bel Air S Pkwy Bel Air, MD 21014 US
# 7              8                    305 S 6th St Boise, ID 83702 US
# 8              9  1132 S Clinton St Clinton & Grenshaw Chicago, ...
# 9             10    4400 Sharon Rd Space G41 Charlotte, NC 28211 US
# 10            11      1109 E. 5th St. Suite 130 Austin, TX 78702 US
# 11            12         240 Bloomfield Ave Bloomfield, NJ 07003 US
# 12            13    400 S Baldwin Ave Ste FC-9 Arcadia, CA 91007 US
# 13            14            316 N Michigan Ave Chicago, IL 60601 US
# 14            15  Post Security - Ab Concourse Food Court A/B Te...
# 15            16                  919 Pearl St Boulder, CO 80302 US
# 16            17  19179 Bear Valley Rd Ste 4 Apple Valley, CA 92...
# 17            18       598 Massachusetts Ave Cambridge, MA 02139 US
# 18            19       8599 W Grand River Ave Brighton, MI 48116 US
# 19            20       2608 Central Ave SE Albuquerque, NM 87106 US
# 20            21  3600 Coors Blvd NW A-800 Albuquerque, NM 87120 US
# 21            22    695 W Waterloo St Canal Winchester, OH 43110 US
# 22            23        1650 28th St Unit 1224 Boulder, CO 80301 US
# 23            24      528 E Green St Ste 101 Champaign, IL 61820 US
# 24            25  1457 S Carson St Ste 102 Carson City, NV 89701 US
# 25            26             2743 N Elston Ave Chicago, IL 60647 US
# 26            27            101 W State St Baton Rouge, LA 70802 US
# 27            28  12697 N Pennsylvania St Ste 100 Carmel, IN 460...
# 28            29    5001 S Cooper St Ste 125 Arlington, TX 76017 US
# 29            30       1558 E Wooster St Bowling Green, OH 43402 US
# 30            31         9430C Colerain Ave Cincinnati, OH 45251 US
# 31            32     4600 Roswell Rd Unit B110 Atlanta, GA 30342 US
# 32            33  6440 Harrison Ave Ste 300 Cincinnati, OH 45247 US
# 33            34                   55 Dodge St Beverly, MA 01915 US
# 34            35               1924 Beacon St Brighton, MA 02135 US
# 35            36             347 Flatbush Ave Brooklyn, NY 11238 US
# 36            37         720 Otay Lakes Rd Chula Vista, CA 91910 US
# 37            38                 774 Broadway Brooklyn, NY 11206 US
# 38            39      8120 San Pedro Dr NE Albuquerque, NM 87113 US
# 39            40              15500 Excelsior Dr Bowie, MD 20716 US
# 40            41      9873 Iron Bridge Rd Chesterfield, VA 23832 US
# 41            42  19825 Belmont Chase Dr Ste 130 Ashburn, VA 201...
# 42            43            65 Drum Hill Rd Chelmsford, MA 01824 US
# 43            44             258 Stetson St Cincinnati, OH 45219 US
# 44            45             36 Market Space Annapolis, MD 21401 US
#
#    Average_Weekly_Sales   Total_Sales
# 0               $21,711  $222,402,809
# 1               $26,898  $275,382,441
# 2                $6,373   $57,586,735
# 3               $29,161  $299,543,953
# 4                $5,053   $45,475,689
# 5               $21,913  $223,756,131
# 6                $8,359   $81,598,275
# 7               $13,133  $129,951,181
# 8                $8,773   $77,789,219
# 9               $26,332  $271,617,714
# 10              $19,277  $193,962,787
# 11              $14,867  $144,287,230
# 12              $27,355  $286,517,704
# 13              $28,785  $288,999,911
# 14               $9,002   $89,133,684
# 15               $7,863   $74,252,425
# 16              $12,954  $127,782,139
# 17              $15,733  $155,114,734
# 18              $20,362  $206,634,862
# 19              $29,508  $301,397,792
# 20              $11,283  $108,117,879
# 21              $15,181  $147,075,649
# 22              $19,776  $198,750,618
# 23              $18,969  $194,016,021
# 24              $10,308  $101,061,179
# 25              $14,554  $143,416,394
# 26              $24,827  $253,855,917
# 27              $18,715  $189,263,681
# 28               $8,159   $77,141,554
# 29               $8,764   $62,716,885
# 30              $19,682  $199,613,905
# 31              $16,352  $166,819,246
# 32               $5,728   $37,160,222
# 33              $13,522  $138,249,763
# 34              $13,804  $131,520,672
# 35               $8,584   $53,412,215
# 36              $10,297   $74,202,740
# 37               $7,492   $55,159,626
# 38              $21,001  $207,445,542
# 39              $13,764  $137,870,310
# 40              $17,976  $181,341,935
# 41              $11,443   $79,565,752
# 42              $13,415   $90,565,435
# 43               $6,039   $43,293,088
# 44              $11,663  $112,395,341

# %% [markdown]
# #### Displays total inspections for each inspector

# %%
sql_inspectors = """
SELECT
    i.Last, COUNT(*) AS Total_Inspections
FROM
    datamart.fact_sales s
JOIN
    datamart.dim_inspectors i ON s.inspector_key = i.inspector_key
GROUP BY
    i.Last;
"""

# %%
df_inspectors = get_sql_dataframe(sql_inspectors, **mysql_args)
df_inspectors
# Out:
#        Last  Total_Inspections
# 0     Brown             140319
# 1    Gentry             140604
# 2  Anderson             140647
